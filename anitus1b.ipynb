# %%
import numpy as np 
# Step 1: Create an integer array 
arr = np.array([1, 2, 3, 4, 5]) 
# Step 2: Cosnvert to float type 
arr_float = arr.astype(float) 
# Step 3: Print the result 
print("Float array:", arr_float)
# Out:
# Float array: [1. 2. 3. 4. 5.]
