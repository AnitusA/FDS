# %%
import numpy as np 
arr = np.array([1, 2, 3, 4, 5]) 
print("Array:",arr) 
arr_float = arr.astype(float) 
print("Float array:", arr_float)
# Out:
# Array: [1 2 3 4 5]
# Float array: [1. 2. 3. 4. 5.]
