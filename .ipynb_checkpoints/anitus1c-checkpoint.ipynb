# %%
import numpy as np 
# Step 1: Generate values from 2 to 10 
matrix = np.arange(2, 11).reshape(3, 3) 
# Step 2: Print the matrix 
print("3x3 Matrix:\n", matrix)
# Out:
# 3x3 Matrix:
#  [[ 2  3  4]
#  [ 5  6  7]
#  [ 8  9 10]]
