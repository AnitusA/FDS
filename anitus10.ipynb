# %%
import pandas as pd 
# Step 1: Create DataFrame 
data = { 
'col1': [1, 2, 3, 4, 7], 
'col2': [4, 5, 6, 9, 5], 
'col3': [7, 8, 12, 1, 11] 
} 
df = pd.DataFrame(data) 
# Step 2: Display original DataFrame 
print("Original DataFrame") 
print(df) 
# Step 3: Count number of columns 
num_cols = df.shape[1] 
print("Number of columns:") 
print(num_cols)
# Out:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11
# Number of columns:
# 3
