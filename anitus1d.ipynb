# %%
import numpy as np 
# Step 1: Create a list of numbers 
num_list = [10, 20, 30, 40, 50] 
# Step 2: Convert to 1D NumPy array 
num_array = np.array(num_list) 
# Step 3: Print the result 
print("1D NumPy array:", num_array)
# Out:
# 1D NumPy array: [10 20 30 40 50]
