# %%
import numpy as np 
# Step 1: Create a null vector of size 10 
null_vector = np.zeros(10) 
# Step 2: Update the sixth value to 11 
null_vector[5] = 11 
# Step 3: Print the result 
print("Updated vector:", null_vector)
# Out:
# Updated vector: [ 0.  0.  0.  0.  0. 11.  0.  0.  0.  0.]
