# %%
import numpy as np 
empty_array = np.empty(5) 
full_array = np.full(5, 7) 
print("Empty array:", empty_array) 
print("Full array:", full_array)
# Out:
# Empty array: [2.16851034e+243 4.27242994e+180 2.11651675e+214 0.00000000e+000
#  0.00000000e+000]
# Full array: [7 7 7 7 7]
